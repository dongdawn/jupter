# %%
cd /home/dongdong/SCR/chignolin/anton/CLN025-0-protein
# Out:
# /scratch/gpfs/dongdong/chignolin/anton/CLN025-0-protein

# %%
import numpy as np

alldata=np.loadtxt('plm.000.out')[:,1:]
for i in range(1,54):
    data=np.loadtxt('plm.%03d.out' %i)[:,1:]
    alldata=np.concatenate((alldata,data),axis=0)

# %%
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)
H, xedges, yedges = np.histogram2d(alldata[:,1], alldata[:,2], bins=[61,61],range=[[-np.pi,np.pi], [-np.pi, np.pi]])
H = H.T+1e-10
pmf = -np.log(H)*0.6757
pmf = pmf - np.min(pmf)

#xedges=np.linspace(0, 0.45, num=100)
#yedges=np.linspace(0, 1, num=100)
#Hn=np.loadtxt('pmf.cs')
fig = plt.figure(figsize=(5.1, 4))
ax = fig.add_subplot(111)
cmap = plt.cm.get_cmap("jet_r")
#CS = plt.contourf(xedges[1:],yedges[1:],H,levels = np.linspace(0,1000000,11),cmap=cmap,extend="max")
#lvls = np.logspace(0,3,15)
cmap.set_over("white")
CS = plt.contourf(xedges[1:],yedges[1:],pmf,levels = np.linspace(0,5,11),cmap=cmap,extend="max")
cbar = plt.colorbar(CS)
#plt.scatter(data_ave[:,0],data_ave[:,1],s=18)
#plt.scatter(data_ave[:,0],data_ave[:,1],c=pcca,cmap='tab20c',s=14)
#plt.errorbar(data_ave[:,2],data_ave[:,0],xerr=data_ave[:,3],yerr=data_ave[:,1],fmt=None)
plt.xlabel(r'a',fontproperties=font_prop)
plt.ylabel(r'b',fontproperties=font_prop)
#plt.xlim(4,14)
#plt.ylim(2,8)
#leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
#leg.get_frame().set_linewidth(0.0)
#leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()+cbar.ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
for label in cbar.ax.get_yticklabels():
    label.set_fontproperties(leg_prop)
plt.savefig('/home/dongdong/SCR/chignolin.run18cv/mc.iter30/anton12.png',dpi=600,bbox_inches='tight')
    #label.set_fontsize(16)
#plt.imshow(HH, interpolation='nearest', origin='low',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],levels = np.linspace(1,6,20))
plt.show()

# %%
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)
H, xedges, yedges = np.histogram2d(alldata[:,4], alldata[:,6], bins=[61,61],range=[[-np.pi,np.pi], [-np.pi, np.pi]])
H = H.T+1e-10
pmf = -np.log(H)*0.6757
pmf = pmf - np.min(pmf)

#xedges=np.linspace(0, 0.45, num=100)
#yedges=np.linspace(0, 1, num=100)
#Hn=np.loadtxt('pmf.cs')
fig = plt.figure(figsize=(5.1, 4))
ax = fig.add_subplot(111)
cmap = plt.cm.get_cmap("jet_r")
#CS = plt.contourf(xedges[1:],yedges[1:],H,levels = np.linspace(0,1000000,11),cmap=cmap,extend="max")
#lvls = np.logspace(0,3,15)
cmap.set_over("white")
CS = plt.contourf(xedges[1:],yedges[1:],pmf,levels = np.linspace(0,5,11),cmap=cmap,extend="max")
cbar = plt.colorbar(CS)
#plt.scatter(data_ave[:,0],data_ave[:,1],s=18)
#plt.scatter(data_ave[:,0],data_ave[:,1],c=pcca,cmap='tab20c',s=14)
#plt.errorbar(data_ave[:,2],data_ave[:,0],xerr=data_ave[:,3],yerr=data_ave[:,1],fmt=None)
plt.xlabel(r'a',fontproperties=font_prop)
plt.ylabel(r'b',fontproperties=font_prop)
#plt.xlim(4,14)
#plt.ylim(2,8)
#leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
#leg.get_frame().set_linewidth(0.0)
#leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()+cbar.ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
for label in cbar.ax.get_yticklabels():
    label.set_fontproperties(leg_prop)
plt.savefig('/home/dongdong/SCR/chignolin.run18cv/mc.iter30/anton46.png',dpi=600,bbox_inches='tight')
    #label.set_fontsize(16)
#plt.imshow(HH, interpolation='nearest', origin='low',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],levels = np.linspace(1,6,20))
plt.show()

# %%
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)
H, xedges, yedges = np.histogram2d(alldata[:,7], alldata[:,8], bins=[61,61],range=[[-np.pi,np.pi], [-np.pi, np.pi]])
H = H.T+1e-10
pmf = -np.log(H)*0.6757
pmf = pmf - np.min(pmf)

#xedges=np.linspace(0, 0.45, num=100)
#yedges=np.linspace(0, 1, num=100)
#Hn=np.loadtxt('pmf.cs')
fig = plt.figure(figsize=(5.1, 4))
ax = fig.add_subplot(111)
cmap = plt.cm.get_cmap("jet_r")
#CS = plt.contourf(xedges[1:],yedges[1:],H,levels = np.linspace(0,1000000,11),cmap=cmap,extend="max")
#lvls = np.logspace(0,3,15)
cmap.set_over("white")
CS = plt.contourf(xedges[1:],yedges[1:],pmf,levels = np.linspace(0,5,11),cmap=cmap,extend="max")
cbar = plt.colorbar(CS)
#plt.scatter(data_ave[:,0],data_ave[:,1],s=18)
#plt.scatter(data_ave[:,0],data_ave[:,1],c=pcca,cmap='tab20c',s=14)
#plt.errorbar(data_ave[:,2],data_ave[:,0],xerr=data_ave[:,3],yerr=data_ave[:,1],fmt=None)
plt.xlabel(r'a',fontproperties=font_prop)
plt.ylabel(r'b',fontproperties=font_prop)
#plt.xlim(4,14)
#plt.ylim(2,8)
#leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
#leg.get_frame().set_linewidth(0.0)
#leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()+cbar.ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
for label in cbar.ax.get_yticklabels():
    label.set_fontproperties(leg_prop)
plt.savefig('/home/dongdong/SCR/chignolin.run18cv/mc.iter30/anton78.png',dpi=600,bbox_inches='tight')
    #label.set_fontsize(16)
#plt.imshow(HH, interpolation='nearest', origin='low',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],levels = np.linspace(1,6,20))
plt.show()

# %%
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)
alldata[alldata<0]=alldata[alldata<0]+2*np.pi
H, xedges, yedges = np.histogram2d(alldata[:,1], alldata[:,2], bins=[31,31],range=[[0,2*np.pi], [0, 2*np.pi]])
H = H.T+1e-10
pmf = -np.log(H)*0.6757
pmf = pmf - np.min(pmf)

#xedges=np.linspace(0, 0.45, num=100)
#yedges=np.linspace(0, 1, num=100)
#Hn=np.loadtxt('pmf.cs')
fig = plt.figure(figsize=(5.1, 4))
ax = fig.add_subplot(111)
cmap = plt.cm.get_cmap("jet_r")
#CS = plt.contourf(xedges[1:],yedges[1:],H,levels = np.linspace(0,1000000,11),cmap=cmap,extend="max")
#lvls = np.logspace(0,3,15)
cmap.set_over("white")
CS = plt.contourf(xedges[1:],yedges[1:],pmf,levels = np.linspace(0,5,11),cmap=cmap,extend="max")
cbar = plt.colorbar(CS)
#plt.scatter(data_ave[:,0],data_ave[:,1],s=18)
#plt.scatter(data_ave[:,0],data_ave[:,1],c=pcca,cmap='tab20c',s=14)
#plt.errorbar(data_ave[:,2],data_ave[:,0],xerr=data_ave[:,3],yerr=data_ave[:,1],fmt=None)
plt.xlabel(r'a',fontproperties=font_prop)
plt.ylabel(r'b',fontproperties=font_prop)
#plt.xlim(4,14)
#plt.ylim(2,8)
#leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
#leg.get_frame().set_linewidth(0.0)
#leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()+cbar.ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
for label in cbar.ax.get_yticklabels():
    label.set_fontproperties(leg_prop)
#plt.savefig('/home/dongdong/SCR/msm_pdz/complex/kcenters_micro400lag400_2/test.png',dpi=600,bbox_inches='tight')
    #label.set_fontsize(16)
#plt.imshow(HH, interpolation='nearest', origin='low',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],levels = np.linspace(1,6,20))
plt.show()

# %%
fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)
plt.hist(data[:,3],bins=50,normed=True)
#xmin, xmax = np.min(data[:,i]), np.max(data[:,i])
# Out:
# /home/dongdong/software/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (array([ 0.05295095,  0.02647547,  0.        ,  0.        ,  0.        ,
#          0.02647547,  0.02647547,  0.07942642,  0.05295095,  0.05295095,
#          0.07942642,  0.10590189,  0.07942642,  0.07942642,  0.07942642,
#          0.05295095,  0.05295095,  0.10590189,  0.37065663,  0.60893588,
#          0.34418115,  0.47655852,  0.47655852,  0.58246041,  0.84721514,
#          0.82073967,  1.29729819,  1.4826265 ,  1.45615103,  1.4826265 ,
#          1.66795481,  1.42967556,  1.56205292,  1.27082272,  1.32377366,
#          0.92664156,  0.74131325,  1.00606798,  0.71483778,  0.74131325,
#          0.6883623 ,  0.52950947,  0.37065663,  0.42360757,  0.10590189,
#          0.10590189,  0.07942642,  0.10590189,  0.05295095,  0.07942642]),
#  array([-2.898445  , -2.85864436, -2.81884372, -2.77904308, -2.73924244,
#         -2.6994418 , -2.65964116, -2.61984052, -2.58003988, -2.54023924,
#         -2.5004386 , -2.46063796, -2.42083732, -2.38103668, -2.34123604,
#         -2.3014354 , -2.26163476, -2.22183412, -2.18203348, -2.14223284,
#         -2.1024322 , -2.06263156, -2.02283092, -1.98303028, -1.94322964,
#         -1.903429  , -1.86362836, -1.82382772, -1.78402708, -1.74422644,
#         -1.7044258 , -1.66462516, -1.62482452, -1.58502388, -1.54522324,
#         -1.5054226 , -1.46562196, -1.42582132, -1.38602068, -1.34622004,
#         -1.3064194 , -1.26661876, -1.22681812, -1.18701748, -1.14721684,
#         -1.1074162 , -1.06761556, -1.02781492, -0.98801428, -0.94821364,
#         -0.908413  ]),
#  <a list of 50 Patch objects>)

# %%
import numpy as np

alldata=np.loadtxt('plm.000.out')[:,1:]
for i in range(1,54):
    data=np.loadtxt('plm.%03d.out' %i)[:,1:]
    alldata=np.concatenate((alldata,data),axis=0)

# %%
iii=23

xlabel=['Rg','Hydrogen bonds','Hydrophobic contacts','Alpha helicity','Beta similarity','Dihedral correlation']
allrange=np.array([np.pi*2]*18+[10,15,12,15,16,14])
H, xedges = np.histogram(alldata[:,iii], bins=101,range=[0,allrange[iii]])
pmf=-np.log(H+1e-7)*0.6757
pmf=pmf-np.min(pmf)

fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)

plt.plot(xedges[1:], pmf,lw=2)

for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
plt.xlabel(xlabel[iii-18],fontproperties=font_prop)
plt.ylabel(r'PMF (kcal/mol)',fontproperties=font_prop)
plt.ylim(-0.5,7)
plt.xlim(1,11.5)
sub.set_yticks(np.linspace(0,6,4))
#sub.set_xticks(np.linspace(0.45,0.85,5))
leg=sub.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
#plt.semilogy()
#plt.savefig('1DPMF.png',dpi=600,bbox_inches='tight')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
iii=0

xlabel=['Rg','Hydrogen bonds','Hydrophobic contacts','Alpha helicity','Beta similarity','Dihedral correlation']
xlabel=['angle']
allrange=np.array([np.pi*2]*18+[10,15,12,15,16,14])
#aa=alldata[:,iii]
#aa[aa<0]=aa+2*np.pi
H, xedges = np.histogram(alldata[:,iii], bins=101,range=[-np.pi,np.pi])
pmf=-np.log(H+1e-7)*0.6757
pmf=pmf-np.min(pmf)

fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)

plt.plot(xedges[1:], pmf,lw=2)

for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
plt.xlabel(xlabel[iii],fontproperties=font_prop)
plt.ylabel(r'PMF (kcal/mol)',fontproperties=font_prop)
plt.ylim(-0.5,7)
plt.xlim(-np.pi,np.pi)
sub.set_yticks(np.linspace(0,6,4))
#sub.set_xticks(np.linspace(0.45,0.85,5))
leg=sub.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
#plt.semilogy()
#plt.savefig('1DPMF.png',dpi=600,bbox_inches='tight')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
aa[aa<0]=aa+2*np.pi
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-479f1ecb20b2> in <module>
# ----> 1 aa[aa<0]=aa+2*np.pi
#
# ValueError: NumPy boolean array indexing assignment cannot assign 106949 input values to the 36025 output values where the mask is true

# %%
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=22)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)
iii=0

xlabel=['Rg','Hydrogen bonds','Hydrophobic contacts','Alpha helicity','Beta similarity','Dihedral correlation']
allrange=np.array([1,19,5.5,14.5,16,14])
H, xedges = np.histogram(alldata[:,iii], bins=201,range=[0,allrange[iii]])
pmf=-np.log(H+1e-7)*0.6757
pmf=pmf-np.min(pmf)

fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)

plt.plot(xedges[1:], pmf,lw=2)

for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
plt.xlabel(r'Rg',fontproperties=font_prop)
plt.ylabel(r'PMF (kcal/mol)',fontproperties=font_prop)
plt.ylim(-0.5,7)
plt.xlim(0.45,0.9)
sub.set_yticks(np.linspace(0,6,4))
sub.set_xticks(np.linspace(0.45,0.85,5))
leg=sub.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
#plt.semilogy()
#plt.savefig('1DPMF.png',dpi=600,bbox_inches='tight')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
iii=5

xlabel=['Rg','Hydrogen bonds','Hydrophobic contacts','Alpha helicity','Beta similarity','Dihedral correlation']
allrange=np.array([1,19,5.5,14.5,16,14])
H, xedges = np.histogram(alldata[:,iii], bins=201,range=[0,allrange[iii]])
pmf=-np.log(H+1e-7)*0.6757
pmf=pmf-np.min(pmf)

fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)

plt.plot(xedges[1:], pmf,lw=2)

for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
plt.xlabel(r'Dihedral correlation',fontproperties=font_prop)
plt.ylabel(r'PMF (kcal/mol)',fontproperties=font_prop)
plt.ylim(-0.5,7)
plt.xlim(1,11)
sub.set_yticks(np.linspace(0,6,4))
#sub.set_xticks(np.linspace(0.45,0.85,5))
leg=sub.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
#plt.semilogy()
#plt.savefig('1DPMF.png',dpi=600,bbox_inches='tight')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
iii=4

xlabel=['Rg','Hydrogen bonds','Hydrophobic contacts','Alpha helicity','Beta similarity','Dihedral correlation']
allrange=np.array([1,19,5.5,14.5,16,14])
H, xedges = np.histogram(alldata[:,iii], bins=201,range=[0,allrange[iii]])
pmf=-np.log(H+1e-7)*0.6757
pmf=pmf-np.min(pmf)

fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)

plt.plot(xedges[1:], pmf,lw=2)

for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
plt.xlabel(xlabel[iii],fontproperties=font_prop)
plt.ylabel(r'PMF (kcal/mol)',fontproperties=font_prop)
plt.ylim(-0.5,7)
plt.xlim(7,15.5)
sub.set_yticks(np.linspace(0,6,4))
#sub.set_xticks(np.linspace(0.45,0.85,5))
leg=sub.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
#plt.semilogy()
#plt.savefig('1DPMF.png',dpi=600,bbox_inches='tight')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
H, xedges, yedges = np.histogram2d(alldata[:,1], alldata[:,2], bins=[201,201],range=[[0,19], [0, 5.5]])

# %%
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)
H, xedges, yedges = np.histogram2d(alldata[:,19], alldata[:,20], bins=[201,201],range=[[0,19], [0, 8]])
H = H.T+1e-10
pmf = -np.log(H)*0.6757
pmf = pmf - np.min(pmf)

#xedges=np.linspace(0, 0.45, num=100)
#yedges=np.linspace(0, 1, num=100)
#Hn=np.loadtxt('pmf.cs')
fig = plt.figure(figsize=(5.1, 4))
ax = fig.add_subplot(111)
cmap = plt.cm.get_cmap("jet_r")
#CS = plt.contourf(xedges[1:],yedges[1:],H,levels = np.linspace(0,1000000,11),cmap=cmap,extend="max")
#lvls = np.logspace(0,3,15)
cmap.set_over("white")
CS = plt.contourf(xedges[1:],yedges[1:],pmf,levels = np.linspace(0,4,9),cmap=cmap,extend="max")
cbar = plt.colorbar(CS)
#plt.scatter(data_ave[:,0],data_ave[:,1],s=18)
#plt.scatter(data_ave[:,0],data_ave[:,1],c=pcca,cmap='tab20c',s=14)
#plt.errorbar(data_ave[:,2],data_ave[:,0],xerr=data_ave[:,3],yerr=data_ave[:,1],fmt=None)
plt.xlabel(r'Hydrogen Bonds',fontproperties=font_prop)
plt.ylabel(r'Hydrophobic Contacts',fontproperties=font_prop)
plt.xlim(4,14)
plt.ylim(2,8)
#leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
#leg.get_frame().set_linewidth(0.0)
#leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()+cbar.ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
for label in cbar.ax.get_yticklabels():
    label.set_fontproperties(leg_prop)
#plt.savefig('/home/dongdong/SCR/msm_pdz/complex/kcenters_micro400lag400_2/test.png',dpi=600,bbox_inches='tight')
    #label.set_fontsize(16)
#plt.imshow(HH, interpolation='nearest', origin='low',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],levels = np.linspace(1,6,20))
plt.show()

# %%
import numpy as np
import os
os.chdir('/home/dongdong/SCR/chignolin/anton/CLN025-0-protein')
alldata=np.loadtxt('bck.0.plm.rg.out')[:,1:]
for i in range(1,54):
    data=np.loadtxt('bck.%d.plm.rg.out' %i)[:,1:]
    alldata=np.concatenate((alldata,data),axis=0)

# %%
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)
H, xedges, yedges = np.histogram2d(alldata[:,5], alldata[:,2], bins=[51,51],range=[[0,19], [0, 19]])
H = H.T+1e-10
pmf = -np.log(H)*0.6757
pmf = pmf - np.min(pmf)

#xedges=np.linspace(0, 0.45, num=100)
#yedges=np.linspace(0, 1, num=100)
#Hn=np.loadtxt('pmf.cs')
fig = plt.figure(figsize=(5.1, 4))
ax = fig.add_subplot(111)
cmap = plt.cm.get_cmap("jet_r")
#CS = plt.contourf(xedges[1:],yedges[1:],H,levels = np.linspace(0,1000000,11),cmap=cmap,extend="max")
#lvls = np.logspace(0,3,15)
cmap.set_over("white")
CS = plt.contourf(xedges[1:],yedges[1:],pmf,levels = np.linspace(0,4,9),cmap=cmap,extend="max")
cbar = plt.colorbar(CS)
#plt.scatter(data_ave[:,0],data_ave[:,1],s=18)
#plt.scatter(data_ave[:,0],data_ave[:,1],c=pcca,cmap='tab20c',s=14)
#plt.errorbar(data_ave[:,2],data_ave[:,0],xerr=data_ave[:,3],yerr=data_ave[:,1],fmt=None)
plt.xlabel(r'Hydrogen Bonds',fontproperties=font_prop)
plt.ylabel(r'Hydrophobic Contacts',fontproperties=font_prop)
plt.xlim(0,14)
plt.ylim(4,12)
#leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
#leg.get_frame().set_linewidth(0.0)
#leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()+cbar.ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
for label in cbar.ax.get_yticklabels():
    label.set_fontproperties(leg_prop)
#plt.savefig('/home/dongdong/SCR/msm_pdz/complex/kcenters_micro400lag400_2/test.png',dpi=600,bbox_inches='tight')
    #label.set_fontsize(16)
#plt.imshow(HH, interpolation='nearest', origin='low',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],levels = np.linspace(1,6,20))
plt.show()

# %%
[1,2,3]+[4]*10
# Out:
# [1, 2, 3, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]

# %%
import numpy as np

# %%
allrange=np.array([np.pi*2]*18+[1,19,8,14])

# %%
allrange[18:]
# Out:
# array([  1.,  19.,   8.,  14.])

# %%
position_a = np.random.uniform(size=18) * np.pi * 2

# %%
position_a
# Out:
# array([ 1.3225557 ,  6.1747157 ,  5.36677527,  3.87734309,  3.95608383,
#         0.26174569,  0.36870838,  4.24206378,  3.85234835,  0.08268032,
#         1.11846783,  1.8262994 ,  0.13497023,  6.00007393,  6.09086322,
#         3.38905526,  3.03885981,  3.18851941])

# %%
import os
os.chdir('/home/dongdong/SCR/chignolin/anton/CLN025-0-protein/')
import mdtraj as md
pdb = md.load_pdb('crystal.pdb')
topology = pdb.topology
CA=topology.select('name CA')
for i in range(54):
    traj = md.load_dcd('CLN025-0-protein-%03d.dcd' %i, top='CLN025-0-protein.pdb')
    rmsds = md.rmsd(traj, pdb, 0,CA)
    np.savetxt('rmsd%03d.dat' %i, rmsds)
    print(np.min(rmsds))
# Out:
# 0.0595779
# 0.0544975
# 0.0581588
# 0.0598391
# 0.0594898
# 0.0565096
# 0.0637352
# 0.0462761
# 0.0531904
# 0.065681
# 0.0596923
# 0.0554495
# 0.057909
# 0.0563266
# 0.0531998
# 0.0610769
# 0.0663236
# 0.0527737
# 0.0501981
# 0.0478222
# 0.0509444
# 0.0581309
# 0.0531245
# 0.0542779
# 0.0532943
# 0.0541354
# 0.0590481
# 0.0603832
# 0.0585628
# 0.0542023
# 0.0679009
# 0.0513583
# 0.0577532
# 0.0620721
# 0.0477483
# 0.047159
# 0.0447714
# 0.0576788
# 0.0520179
# 0.0447176
# 0.0603939
# 0.0634153
# 0.0562571
# 0.0563431
# 0.0557471
# 0.0535464
# 0.056109
# 0.0582297
# 0.0553794
# 0.055184
# 0.0578406
# 0.0610789
# 0.0561052
# 0.064506

# %%
rmsds = md.rmsd(traj, pdb, 0,CA)

# %%
rmsds
# Out:
# array([ 0.36732772,  0.28539234,  0.38885334, ...,  0.14615083,
#         0.08944268,  0.11391676], dtype=float32)

# %%
plt.scatter(range(len(rmsds)),rmsds)
