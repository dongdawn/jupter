# %%
cd /home/dongdong/SCR/covid-19
# Out:
# /scratch/gpfs/dongdong/covid-19

# %%
dataob=open('results_FDA_openbabel.csv','r')
alldict={}
for line in dataob.readlines()[1:]:
    line=line.strip()
    infor=line.split('\t')
    name=infor[2]
    score=infor[1]
    alldict[name]=[]
dataob=open('results_FDA_openbabel.csv','r')
for line in dataob.readlines()[1:]:
    line=line.strip()
    infor=line.split('\t')
    name=infor[2]
    print(name)
    score=infor[1]
    alldict[name].append(score)
sdict={}
for key in alldict:
    sscore=np.min(list(np.float_(alldict[key])))
    sdict[key]=sscore
dict_ob=sorted(sdict.items(),key=lambda item:item[1])
wf=open('openbabel.csv','w')
for aa in dict_ob:
    wf.write(aa[0]+'\t'+str(aa[1])+'\n')
wf.close()
# Out:
# Tadalafil (Cialis)
# Tadalafil (Cialis)
# Tadalafil (Cialis)
# Tadalafil (Cialis)
# GSK1120212 (Trametinib)
# Bictegravir
# Tadalafil (Cialis)
# Bictegravir
# Bictegravir
# Bictegravir
# Tadalafil (Cialis)
# Bictegravir
# Bictegravir
# Nilotinib (AMN-107)
# Bictegravir
# Nilotinib hydrochloride
# Nilotinib (AMN-107)
# Bictegravir
# Bictegravir
# Bictegravir
# Nilotinib (AMN-107)
# Icotinib
# Nilotinib hydrochloride
# Bictegravir
# Nilotinib (AMN-107)
# Bictegravir
# Radotinib
# Nilotinib hydrochloride
# Nilotinib hydrochloride
# Nilotinib hydrochloride
# Nilotinib hydrochloride
# Nilotinib hydrochloride
# Nilotinib hydrochloride
# Nilotinib (AMN-107)
# Nilotinib hydrochloride
# Nilotinib hydrochloride
# Icotinib
# Nilotinib hydrochloride
# Radotinib
# Icotinib
# Icotinib
# Daunorubicin HCl (Daunomycin HCl)
# Nilotinib (AMN-107)
# Radotinib
# Rifabutin
# Nilotinib hydrochloride
# Icotinib
# Radotinib
# PCI-32765 (Ibrutinib)
# Eltrombopag
# Radotinib
# CB-5083
# Radotinib
# Radotinib
# ...

# %%
import numpy as np

np.min(list(np.float_(alldict['Ipragliflozin (ASP1941)'])))
# Out:
# -7.5

# %%
dataob=open('results_FDA_gypsum_dl.csv','r')
alldict={}
for line in dataob.readlines()[1:]:
    line=line.strip()
    infor=line.split('\t')
    name=infor[3]
    score=infor[1]
    alldict[name]=[]
dataob=open('results_FDA_gypsum_dl.csv','r')
for line in dataob.readlines()[1:]:
    line=line.strip()
    infor=line.split('\t')
    name=infor[3]
    print(name)
    score=infor[1]
    alldict[name].append(score)
sdict={}
for key in alldict:
    sscore=np.min(list(np.float_(alldict[key])))
    sdict[key]=sscore
dict_dl=sorted(sdict.items(),key=lambda item:item[1])
wf=open('gypsum_dl.csv','w')
for aa in dict_dl:
    wf.write(aa[0]+'\t'+str(aa[1])+'\n')
wf.close()
# Out:
# Nilotinib (AMN-107)
# Enzastaurin (LY317615)
# Enzastaurin (LY317615)
# Tannic acid
# Irinotecan HCl Trihydrate (Campto)
# Digoxin
# Irinotecan HCl Trihydrate (Campto)
# Nilotinib hydrochloride
# Bromocriptine Mesylate
# Irinotecan HCl Trihydrate (Campto)
# Enzastaurin (LY317615)
# Bromocriptine Mesylate
# Dihydroergotamine Mesylate
# Irinotecan HCl Trihydrate (Campto)
# Bictegravir
# Olaparib (AZD2281, Ku-0059436)
# Dihydroergotamine Mesylate
# Dihydroergotamine Mesylate
# Bictegravir
# Bictegravir
# Tadalafil (Cialis)
# Bromocriptine Mesylate
# VX-809 (Lumacaftor)
# Tannic acid
# Elbasvir
# Tadalafil (Cialis)
# Radotinib
# Tadalafil (Cialis)
# Tadalafil (Cialis)
# Tadalafil (Cialis)
# Tadalafil (Cialis)
# Radotinib
# Bictegravir
# Chlortetracycline HCl
# Irinotecan HCl Trihydrate (Campto)
# Ammonium Glycyrrhizate
# Dihydroergotamine Mesylate
# Tannic acid
# Olaparib (AZD2281, Ku-0059436)
# Proanthocyanidins
# Proanthocyanidins
# Bromocriptine Mesylate
# Diammonium Glycyrrhizinate
# ...

# %%
data_dl=open('gypsum_dl.csv','r')
dict_dl={}
for line in data_dl.readlines():
    line=line.strip()
    infor=line.split('\t')
    name=infor[0]
    score=infor[1]
    dict_dl[name]=score
    
data_ob=open('openbabel.csv','r')
dict_ob={}
for line in data_ob.readlines():
    line=line.strip()
    infor=line.split('\t')
    name=infor[0]
    score=infor[1]
    dict_ob[name]=score
allname=[]
all_dl=[]
all_ob=[]
for key in dict_dl:
    if key in dict_ob:
        print(key+'  '+str(dict_dl[key])+'  '+str(dict_ob[key])+'\n')
        allname.append(key)
        all_dl.append(float(dict_dl[key]))
        all_ob.append(float(dict_ob[key]))
    #else:
        #print(key+'  '+str(dict_dl[key])+'  none'+'\n')
# Out:
# Nilotinib (AMN-107)  -10.0  -9.5
#
# Enzastaurin (LY317615)  -9.9  -8.7
#
# Tannic acid  -9.8  -7.4
#
# Irinotecan HCl Trihydrate (Campto)  -9.8  -9.1
#
# Nilotinib hydrochloride  -9.7  -9.5
#
# Bromocriptine Mesylate  -9.7  -9.0
#
# Dihydroergotamine Mesylate  -9.6  -9.2
#
# Bictegravir  -9.5  -9.8
#
# Olaparib (AZD2281, Ku-0059436)  -9.5  -8.7
#
# Tadalafil (Cialis)  -9.5  -9.9
#
# VX-809 (Lumacaftor)  -9.4  -9.1
#
# Elbasvir  -9.4  -8.2
#
# Radotinib  -9.4  -9.4
#
# Chlortetracycline HCl  -9.4  -7.5
#
# Proanthocyanidins  -9.3  -9.1
#
# Eltrombopag  -9.3  -9.3
#
# Eltrombopag olamine  -9.2  -9.1
#
# Hesperidin  -9.2  -8.6
#
# Rutin (Rutoside)  -9.2  -8.4
#
# Venetoclax (ABT-199, GDC-0199)  -9.2  -8.3
#
# Baloxavir marboxil  -9.1  -7.7
#
# Nintedanib (BIBF 1120)  -9.1  -8.7
#
# Diosmin  -9.1  -9.0
#
# Raltegravir potassium  -9.1  -8.9
#
# GSK1120212 (Trametinib)  -9.1  -9.8
#
# Ponatinib (AP24534)  -9.1  -8.0
#
# Scutellarin  -9.1  -8.3
#
# Imatinib (STI571)  -9.0  -8.4
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=20)
leg_prop = font_manager.FontProperties(fname=font_path, size=17)
fig, ax = plt.subplots(figsize=(6,4))
X=np.arange(len(allname[:20]))
plt.bar(X,all_dl[:20],color='b',width=0.3,label='gypsum_dl')
plt.bar(X+0.25,all_ob[:20],color='r',width=0.3,label='openbabel')
plt.xticks(X,allname[:20])
ax.set_ylabel(r'vina score',fontproperties=font_prop)
#ax.set_xlabel('iteration',fontproperties=font_prop)
plt.ylim(-7,-11)
#plt.xlim(0,180)
leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(14)
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
#plt.savefig('cluster'+str(i)+'.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
data_dl=open('gypsum_dl.csv','r')
dict_dl={}
for line in data_dl.readlines():
    line=line.strip()
    infor=line.split('\t')
    name=infor[0]
    score=infor[1]
    dict_dl[name]=score
    
data_ob=open('openbabel.csv','r')
dict_ob={}
for line in data_ob.readlines():
    line=line.strip()
    infor=line.split('\t')
    name=infor[0]
    score=infor[1]
    dict_ob[name]=score
allname2=[]
all_dl2=[]
all_ob2=[]
for key in dict_ob:
    if key in dict_dl:
        print(key+'  '+str(dict_dl[key])+'  '+str(dict_ob[key])+'\n')
        allname2.append(key)
        all_dl2.append(float(dict_dl[key]))
        all_ob2.append(float(dict_ob[key]))
    #else:
        #print(key+'  '+str(dict_dl[key])+'  none'+'\n')
# Out:
# Tadalafil (Cialis)  -9.5  -9.9
#
# GSK1120212 (Trametinib)  -9.1  -9.8
#
# Bictegravir  -9.5  -9.8
#
# Nilotinib (AMN-107)  -10.0  -9.5
#
# Nilotinib hydrochloride  -9.7  -9.5
#
# Icotinib  -8.5  -9.4
#
# Radotinib  -9.4  -9.4
#
# Daunorubicin HCl (Daunomycin HCl)  -8.6  -9.3
#
# Rifabutin  -7.8  -9.3
#
# PCI-32765 (Ibrutinib)  -9.0  -9.3
#
# Eltrombopag  -9.3  -9.3
#
# CB-5083  -9.0  -9.3
#
# Clofazimine  -8.9  -9.3
#
# Dihydroergotamine Mesylate  -9.6  -9.2
#
# Eltrombopag olamine  -9.2  -9.1
#
# VX-809 (Lumacaftor)  -9.4  -9.1
#
# Proanthocyanidins  -9.3  -9.1
#
# Rutin hydrate  -9.0  -9.1
#
# Irinotecan HCl Trihydrate (Campto)  -9.8  -9.1
#
# Deferasirox (Exjade)  -8.7  -9.0
#
# Sitafloxacin hydrate  -7.7  -9.0
#
# Rolapitant  -8.8  -9.0
#
# Doxorubicin (Adriamycin) HCl  -8.7  -9.0
#
# Lopinavir (ABT-378)  -8.1  -9.0
#
# Bromocriptine Mesylate  -9.7  -9.0
#
# Diosmin  -9.1  -9.0
#
# Teniposide (Vumon)  -8.6  -8.9
#
# Raltegravir potassium  -9.1  -8.9
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=20)
leg_prop = font_manager.FontProperties(fname=font_path, size=17)
fig, ax = plt.subplots(figsize=(6,4))
X=np.arange(len(allname2[:20]))
plt.bar(X,all_dl2[:20],color='b',width=0.3,label='gypsum_dl')
plt.bar(X+0.25,all_ob2[:20],color='r',width=0.3,label='openbabel')
plt.xticks(X,allname2[:20])
ax.set_ylabel(r'vina score',fontproperties=font_prop)
#ax.set_xlabel('iteration',fontproperties=font_prop)
plt.ylim(-7,-11)
#plt.xlim(0,180)
leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(14)
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
#plt.savefig('cluster'+str(i)+'.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
dataob=open('results_FDA_openbabel.csv','r')
alldict={}
for line in dataob.readlines()[1:]:
    line=line.strip()
    infor=line.split('\t')
    name=infor[2]
    score=infor[1]
    alldict[name]=[]
    
dataob=open('results_FDA_gypsum_dl.csv','r')
for line in dataob.readlines()[1:]:
    line=line.strip()
    infor=line.split('\t')
    name=infor[3]
    score=infor[1]
    alldict[name]=[]

dataob=open('results_FDA_openbabel.csv','r')
for line in dataob.readlines()[1:]:
    line=line.strip()
    infor=line.split('\t')
    name=infor[2]
    score=infor[1]
    alldict[name].append(score)
dataob=open('results_FDA_gypsum_dl.csv','r')
for line in dataob.readlines()[1:]:
    line=line.strip()
    infor=line.split('\t')
    name=infor[3]
    score=infor[1]
    alldict[name].append(score)    

    
sdict={}
for key in alldict:
    sscore=np.min(list(np.float_(alldict[key])))
    sdict[key]=sscore
dict_ob=sorted(sdict.items(),key=lambda item:item[1])
wf=open('all.csv','w')
for aa in dict_ob:
    wf.write(aa[0]+'\t'+str(aa[1])+'\n')
wf.close()

# %%
dataob=open('seqgen.dat','r')
alldict={}
for line in dataob.readlines()[1:]:
    line=line.strip()
    infor=line.split('\t')
    name=infor[2]
    score=infor[1]
    alldict[name]=[]
dataob=open('seqgen.dat','r')
for line in dataob.readlines()[1:]:
    line=line.strip()
    infor=line.split('\t')
    name=infor[2]
    score=infor[1]
    alldict[name].append(score)
sdict={}
for key in alldict:
    sscore=np.min(list(np.float_(alldict[key])))
    sdict[key]=sscore
dict_ob=sorted(sdict.items(),key=lambda item:item[1])
wf=open('seqgen_set.dat','w')
for aa in dict_ob:
    wf.write(aa[0]+'\t'+str(aa[1])+'\n')
wf.close()
