# %%
cd /home/dongdong/SCR/peptoid/data_dongdong
# Out:
# /scratch/gpfs/dongdong/peptoid/data_dongdong

# %%
import parmed as pmd

struct = pmd.load_file('chi3.psf')
struct.load_parameters(
    pmd.charmm.CharmmParameterSet('parameters/CHI_N.par','parameters/DMA.CHI.NTOID.par','parameters/par_NTOID.par','parameters/par_to_refit.prm','top_pep_ntoid.rtf','parameters/toppar_water.par','parameters/par_all36_cgenff.prm','parameters/par_all36_cgenff.prm')
)
#struct.coordinates = pmd.load_file('chi3_2.pdb').coordinates
struct.save('gromacs4.top')
#struct.save('gromacs3.gro')
# Out:
# /home/dongdong/software/anaconda3/envs/py3.6/lib/python3.6/site-packages/parmed/charmm/parameters.py:713: ParameterWarning: Atom type HT not present in AtomType list
#   warnings.warn('Atom type %s not present in AtomType list' % key, ParameterWarning)

# %%
params = pmd.charmm.CharmmParameterSet('parameters/par_all36_cgenff.prm','parameters/CHI_N.par','parameters/DMA.CHI.NTOID.par','parameters/par_NTOID.par','parameters/par_to_refit.prm','top_pep_ntoid.rtf')

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=12)
leg_prop = font_manager.FontProperties(fname=font_path, size=10)
fig = plt.figure(figsize=(10,8))
data=np.loadtxt('/home/dongdong/SCR/peptoid/data_dongdong/plm.out')[::100]
#print(data)
for i in range(9):
    sub = fig.add_subplot(3,3,i+1)
    sub.scatter(data[:,0]/1000,data[:,i+1],s=1)
    sub.set_ylabel(r'angle',fontproperties=font_prop)
    sub.set_xlabel(r'time (ns)',fontproperties=font_prop)
    #sub.tick_params(direction="in", length=1)
    plt.ylim(-3.2,3.2)
    #plt.xlim(25,55)
    #ax.set_yticks(np.linspace(0,2,5))
    #ax.set_yticklabels([0,0.5,1,2])
    #leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
    #leg.get_frame().set_linewidth(0.0)
    #leg.get_frame().set_alpha(0.1)
    for label in (sub.get_xticklabels() + sub.get_yticklabels()):
        label.set_fontproperties(font_prop)
        label.set_fontsize(10)
    #plt.savefig('plm.png',dpi=300,bbox_inches='tight')
plt.tight_layout(pad=0.4, w_pad=0.4, h_pad=0.4)
plt.show()
# Out:
# [[  0.00000000e+00  -3.05574300e+00  -1.47040400e+00 ...,   2.05110000e-02
#     1.62156600e+00   3.11457900e+00]
#  [  2.00000010e+01  -3.03439200e+00  -1.72858600e+00 ...,   7.59100000e-03
#     1.52616700e+00  -3.07280900e+00]
#  [  4.00000020e+01   3.07797100e+00  -1.64772000e+00 ...,  -2.42001000e-01
#     1.41060700e+00   2.77853000e+00]
#  ...,
#  [  9.99600047e+04  -2.82524500e+00  -1.33758700e+00 ...,   5.91070000e-02
#     1.72889900e+00   2.71525500e+00]
#  [  9.99800047e+04  -3.06164300e+00  -1.37415300e+00 ...,  -1.45269000e-01
#     1.66846800e+00   2.60212000e+00]
#  [  1.00000005e+05  -2.93895600e+00  -1.37582900e+00 ...,  -1.55630000e-02
#     1.38854700e+00  -3.04023200e+00]]

# %%
cd /scratch/gpfs/dongdong/peptoid/chi1
# Out:
# /scratch/gpfs/dongdong/peptoid/chi1

# %%
import parmed as pmd

struct = pmd.load_file('chi1_2.psf')
struct.load_parameters(
    pmd.charmm.CharmmParameterSet('parameters/CHI_N.par','parameters/DMA.CHI.NTOID.par','parameters/par_NTOID.par','parameters/par_to_refit.prm','top_pep_ntoid.rtf','parameters/toppar_water.par','parameters/par_all36_cgenff.prm','parameters/par_all36_cgenff.prm')
)
struct.coordinates = pmd.load_file('chi1_2.pdb').coordinates
struct.save('gromacs.top')
struct.save('gromacs.gro')
# Out:
# /home/dongdong/software/anaconda3/envs/py3.6/lib/python3.6/site-packages/parmed/charmm/parameters.py:713: ParameterWarning: Atom type HT not present in AtomType list
#   warnings.warn('Atom type %s not present in AtomType list' % key, ParameterWarning)

# %%
struct = pmd.load_file('chi1_2.psf')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/software/anaconda3/envs/py3.6/lib/python3.6/site-packages/parmed/charmm/psf.py in newfunc(*args, **kwargs)
#      33         try:
# ---> 34             return func(*args, **kwargs)
#      35         except IndexError as e:
#
# ~/software/anaconda3/envs/py3.6/lib/python3.6/site-packages/parmed/charmm/psf.py in __init__(self, psf_name)
#     210             for i in range(natom):
# --> 211                 words = psfsections['NATOM'][1][i].split()
#     212                 atid = int(words[0])
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# CharmmError                               Traceback (most recent call last)
# <ipython-input-65-1c4b99df5e28> in <module>
# ----> 1 struct = pmd.load_file('chi1_2.psf')
#
# ...

# %%
struct.load_dataframe

# %%
import numpy as np
np.random.uniform(size=4) * np.pi * 2
# Out:
# array([ 5.23658595,  4.45762107,  5.92796093,  6.23909137])
