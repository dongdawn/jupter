# %%
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)

data=np.loadtxt('fe.out')
fig = plt.figure(figsize=(5.1, 4))
ax = fig.add_subplot(111)
cmap = plt.cm.get_cmap("jet_r")
#CS = plt.contourf(xedges[1:],yedges[1:],H,levels = np.linspace(0,1000000,11),cmap=cmap,extend="max")
#lvls = np.logspace(0,3,15)
cmap.set_over("white")
xi = np.linspace(-np.pi, np.pi, 61)
CS = plt.contourf(xi,xi,np.reshape(-data[:,2]/4.18,(-1,61)).T,levels = np.linspace(0,15,16),cmap=cmap,extend="max")
#CS = plt.contourf(xi,xi,np.reshape(data[:,2]/4.18,(-1,61)),cmap=cmap,extend="max")
cbar = plt.colorbar(CS)
#plt.scatter(data_ave[:,0],data_ave[:,1],s=18)
#plt.scatter(data_ave[:,0],data_ave[:,1],c=pcca,cmap='tab20c',s=14)
#plt.errorbar(data_ave[:,2],data_ave[:,0],xerr=data_ave[:,3],yerr=data_ave[:,1],fmt=None)
plt.xlabel(r'a',fontproperties=font_prop)
plt.ylabel(r'a',fontproperties=font_prop)
#plt.xlim(0,0.45)
#plt.ylim(0,1)
#leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
#leg.get_frame().set_linewidth(0.0)
#leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()+cbar.ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
for label in cbar.ax.get_yticklabels():
    label.set_fontproperties(leg_prop)
plt.savefig('test.png',dpi=600,bbox_inches='tight')
    #label.set_fontsize(16)
#plt.imshow(HH, interpolation='nearest', origin='low',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],levels = np.linspace(1,6,20))
plt.show()

# %%
cd /scratch/gpfs/dongdong/chi1.run02
# Out:
# /scratch/gpfs/dongdong/chi1.run02

# %%
data45=np.loadtxt('/home/dongdong/SCR/chi1.run02/iter45/fe.out')
data50=np.loadtxt('/home/dongdong/SCR/chi1.run02/iter50/fe.out')
data55=np.loadtxt('/home/dongdong/SCR/chi1.run02/iter55/fe.out')

# %%
phi45 = -np.sum(np.array(data45[:,2]).reshape((25,-1)),axis=1)*np.pi/12/4.18
phi50 = -np.sum(np.array(data50[:,2]).reshape((25,-1)),axis=1)*np.pi/12/4.18
phi55 = -np.sum(np.array(data55[:,2]).reshape((25,-1)),axis=1)*np.pi/12/4.18

# %%
np.array(data55[:,2]).reshape((25,-1))
# Out:
# array([[-38.33761 , -38.35391 , -39.419596, -37.112779, -31.588872,
#         -24.243961, -20.845413, -22.664907, -30.205619, -41.259184,
#         -51.028864, -56.433083, -57.529923, -54.757334, -48.840606,
#         -38.250912, -27.824939, -21.697931, -21.315283, -24.871393,
#         -32.192485, -37.231846, -38.212483, -38.195884, -38.33761 ],
#        [-36.789425, -35.577869, -34.046676, -31.682366, -27.668742,
#         -24.65686 , -24.694421, -30.640189, -38.796917, -46.973366,
#         -53.225746, -56.970603, -56.966168, -53.024393, -45.130704,
#         -32.607454, -21.458629, -16.19922 , -17.657634, -25.454852,
#         -35.678004, -39.800988, -39.44987 , -37.946816, -36.789425],
#        [-31.482388, -29.065637, -27.223702, -25.027194, -22.203746,
#         -21.971545, -25.548518, -34.502484, -42.607054, -48.143122,
#         -52.32737 , -54.5954  , -53.826196, -48.367174, -38.461844,
#         -24.290318, -14.323196, -10.506638, -13.259095, -22.246677,
#         -32.774821, -37.561589, -38.131994, -34.612838, -31.482388],
#        [-22.620402, -20.343426, -19.40436 , -18.385484, -17.263896,
#         -18.435756, -24.231765, -34.657455, -41.153704, -46.649042,
#         -50.044604, -51.251097, -49.237387, -42.792893, -30.746759,
#         -18.439729,  -9.674149,  -6.455848,  -9.102083, -16.056431,
#         -25.885859, -31.083144, -31.026396, -27.081381, -22.620402],
#        [-13.031353, -11.050553, -11.323573, -11.405437, -10.745404,
#         -12.18305 , -17.920289, -28.388165, -37.219768, -43.233012,
#         -46.900115, -47.085654, -43.108311, -35.36884 , -26.068016,
#         -16.217117,  -8.996772,  -5.812314,  -6.714448, -11.061561,
#         -16.725124, -20.258057, -20.128048, -16.533466, -13.031353],
#        [ -4.666905,  -4.153053,  -4.971537,  -5.632414,  -5.50121 ,
#          -6.792803, -10.609665, -19.500174, -30.183307, -37.56479 ,
#         -40.839324, -40.453732, -37.38055 , -32.866875, -26.788159,
#         -19.89236 , -13.122354,  -9.541248,  -8.284661,  -8.776857,
#          -9.604779, -10.755658, -10.18754 ,  -7.329147,  -4.666905],
#        [ -0.755549,  -0.690832,  -2.665421,  -4.167208,  -4.898734,
#          -5.379206,  -7.898322, -13.515982, -20.864784, -29.375381,
#         -32.580994, -33.782089, -34.604349, -33.655724, -32.847713,
#         -29.380836, -24.368636, -16.665687, -11.819932,  -8.439581,
#          -6.090488,  -5.459364,  -4.679783,  -2.551513,  -0.755549],
#        [ -1.731622,  -3.429549,  -6.317943,  -8.905446, -10.142386,
#          -9.614641, -10.168451, -12.102121, -16.116486, -21.989054,
#         -27.242121, -31.159526, -34.255927, -37.066087, -38.240986,
#         -37.643682, -33.410094, -25.799679, -16.33629 ,  -9.184145,
#          -6.388957,  -5.458422,  -4.087436,  -2.177273,  -1.731622],
#        [ -8.62163 , -11.79228 , -16.63835 , -20.037633, -20.380416,
#         -17.926187, -15.439191, -14.166925, -15.303745, -19.688112,
#         -25.100162, -31.775269, -36.240891, -39.788129, -42.015254,
#         -42.102256, -40.5318  , -33.180495, -21.827981, -13.968949,
#         -10.421844,  -9.705037,  -8.39939 ,  -7.357649,  -8.62163 ],
#        [-20.931059, -25.911851, -31.845008, -35.521213, -33.18271 ,
#         -26.737441, -20.092513, -16.452519, -16.793614, -21.100495,
#         -28.514254, -35.402908, -39.570938, -43.047089, -44.454786,
#         -44.441418, -44.509978, -38.950027, -28.459669, -20.647886,
#         -18.281131, -18.476635, -17.956169, -18.131989, -20.931059],
#        [-36.082364, -41.711266, -46.553291, -48.127187, -43.483757,
#         -33.33848 , -24.62741 , -20.444736, -21.559954, -27.080954,
#         -34.606871, -41.061112, -44.322751, -45.418758, -45.873419,
#         -46.53445 , -44.903209, -41.20814 , -32.153727, -27.318224,
#         -27.752577, -29.783637, -30.92925 , -32.616042, -36.082364],
#        [-51.344265, -52.19433 , -53.483021, -53.710865, -47.48706 ,
#         -37.516566, -29.724231, -27.223007, -29.904973, -34.497965,
#         -39.853891, -44.485212, -47.469768, -47.344253, -46.29639 ,
#         -45.004806, -42.797526, -39.054822, -33.771752, -33.860416,
#         -37.640646, -42.452986, -45.172537, -48.365606, -51.344265],
#        [-56.411139, -54.349467, -52.950568, -51.307249, -45.373174,
#         -37.85628 , -33.263445, -34.138827, -38.000603, -41.910243,
#         -44.639715, -46.983347, -47.816436, -46.991888, -44.510194,
#         -41.413865, -37.572014, -33.750606, -33.956993, -38.45023 ,
#         -46.548773, -53.051944, -55.815891, -56.896473, -56.411139],
#        [-50.082997, -46.271564, -43.672369, -41.809951, -37.663126,
#         -34.217229, -35.02366 , -40.123816, -42.947327, -45.762603,
#         -47.4192  , -47.449226, -46.336813, -44.414883, -40.29089 ,
#         -34.544129, -29.874806, -27.123344, -30.14284 , -38.910375,
#         -49.019475, -54.343745, -55.995682, -54.384265, -50.082997],
#        [-34.887302, -31.370342, -29.702134, -29.240602, -27.726846,
#         -27.666048, -32.630338, -40.683793, -43.708227, -45.294699,
#         -47.150584, -47.001265, -44.304303, -40.103487, -34.068286,
#         -27.455492, -22.414654, -21.757917, -25.810562, -34.183447,
#         -43.609832, -47.425309, -47.179465, -41.184888, -34.887302],
#        [-19.225181, -16.762095, -16.87945 , -17.276738, -17.63749 ,
#         -20.018741, -27.638169, -37.431562, -41.383183, -43.267813,
#         -44.514274, -44.396092, -41.444277, -36.020878, -29.018127,
#         -22.513013, -19.073734, -18.702787, -22.722929, -27.963996,
#         -32.963271, -34.253411, -30.628704, -24.242839, -19.225181],
#        [ -7.32813 ,  -6.238844,  -7.484426,  -8.855491,  -9.579785,
#         -12.886747, -21.210776, -30.643928, -37.319586, -40.49372 ,
#         -41.632989, -40.41145 , -36.615835, -31.337083, -26.817219,
#         -22.71107 , -19.75094 , -18.429646, -18.403315, -19.150328,
#         -20.018085, -19.159744, -15.787063, -10.840888,  -7.32813 ],
#        [ -0.614716,  -1.175992,  -3.286883,  -4.847035,  -5.644793,
#          -8.806927, -15.016414, -22.639713, -30.302236, -35.993226,
#         -36.568561, -34.173609, -31.215643, -29.608529, -28.480107,
#         -27.075069, -22.289065, -17.251195, -13.242586, -10.687163,
#          -9.323695,  -8.50339 ,  -5.809578,  -2.534433,  -0.614716],
#        [ -0.      ,  -2.166643,  -5.066722,  -6.492957,  -6.75716 ,
#          -8.0245  , -11.360174, -14.531919, -20.2393  , -26.417944,
#         -28.150133, -28.61526 , -30.002019, -31.966844, -34.113103,
#         -32.350592, -25.308398, -17.045646, -10.378828,  -6.352857,
#          -4.511431,  -3.537818,  -2.11504 ,  -0.366497,   0.      ],
#        [ -5.137265,  -8.05107 , -11.521302, -12.215593, -11.060294,
#          -9.67347 ,  -8.165828,  -8.566468, -12.117925, -18.102398,
#         -23.397026, -28.63461 , -33.746255, -37.852278, -38.903162,
#         -36.909909, -31.033007, -20.91426 , -11.71809 ,  -6.77757 ,
#          -5.127968,  -5.004612,  -4.551247,  -3.97722 ,  -5.137265],
#        [-13.923507, -17.705075, -21.406496, -21.132757, -17.688037,
#         -11.858864,  -6.784286,  -5.217715,  -8.311887, -15.563883,
#         -24.958236, -34.124999, -41.518988, -44.890925, -44.287027,
#         -41.145858, -36.407326, -27.510445, -17.110558, -11.560926,
#         -10.501762, -11.474538, -12.141787, -12.070698, -13.923507],
#        [-23.083934, -27.617424, -31.995098, -31.366846, -25.828661,
#         -15.780996,  -7.924036,  -5.300375,  -8.300016, -17.188462,
#         -29.807502, -41.489805, -46.951279, -48.772796, -47.614459,
#         -43.766716, -38.308102, -30.502117, -21.824797, -16.409131,
#         -16.219862, -17.993043, -19.90135 , -20.77979 , -23.083934],
#        [-30.60461 , -34.256839, -38.959231, -38.549408, -31.933457,
#         -19.896443, -10.958961,  -8.27216 , -12.333235, -22.560928,
#         -36.689012, -46.665993, -52.211914, -52.163763, -49.487874,
#         -44.156223, -37.074728, -29.868141, -21.867211, -19.010204,
#         -20.655566, -24.230171, -27.041634, -27.965359, -30.60461 ],
#        [-35.266329, -38.143386, -40.712268, -40.42104 , -33.529488,
#         -21.764348, -14.894386, -14.014107, -19.48558 , -30.876023,
#         -44.275518, -52.631729, -55.4922  , -54.60304 , -50.015201,
#         -42.303183, -33.361929, -25.748024, -21.205928, -21.836954,
#         -25.461435, -30.104881, -33.510907, -34.506219, -35.266329],
#        [-38.33761 , -38.35391 , -39.419596, -37.112779, -31.588872,
#         -24.243961, -20.845413, -22.664907, -30.205619, -41.259184,
#         -51.028864, -56.433083, -57.529923, -54.757334, -48.840606,
#         -38.250912, -27.824939, -21.697931, -21.315283, -24.871393,
#         -32.192485, -37.231846, -38.212483, -38.195884, -38.33761 ]])

# %%
cd /home/dongdong/SCR/chi1.run02/
# Out:
# /scratch/gpfs/dongdong/chi1.run02

# %%
for i in [1,3,5,7]:
    dirname='iter%d0' %i
    data=np.loadtxt(dirname+'/fes1d2.out')
    newarray=[]
    for aa in data:
        if aa[0]<0:
            bb=aa[0]+2*np.pi
        else:
            bb=aa[0]
        temp=[]
        temp.append(bb)
        temp.append(aa[1])
        temp.append(aa[2])
        temp.append(aa[3])
        temp.append(aa[4])
        temp.append(aa[5])
        temp.append(aa[6])
        temp=np.array(temp)
        newarray.append(temp)
    newarray=np.array(newarray)
    newarray = newarray[newarray[:,0].argsort()]
    print(np.max(newarray[:,4:]/4.184))
    np.savetxt('fes1d2_iter'+str(i)+'.out',newarray,fmt='%.4e')
# Out:
# 0.7291916826
# 0.335839866157
# 0.165998565966
# 0.111703632887

# %%
cd /home/dongdong/SCR/chi1.run02/data
# Out:
# /scratch/gpfs/dongdong/chi1.run02/data

# %%
for i in [1,2,3,4,5,6]:
    dirname='iter%d0' %i
    data=np.loadtxt(dirname+'/fes1d2.out')
    newarray=[]
    for aa in data:
        if aa[0]<0:
            bb=aa[0]+2*np.pi
        else:
            bb=aa[0]
        temp=[]
        temp.append(bb)
        temp.append(aa[1])
        temp.append(aa[2])
        temp.append(aa[3])
        temp.append(aa[4])
        temp.append(aa[5])
        temp.append(aa[6])
        temp=np.array(temp)
        newarray.append(temp)
    newarray=np.array(newarray)
    newarray = newarray[newarray[:,0].argsort()]
    print(np.max(newarray[:,4:]/4.184))
    np.savetxt('fes1d2_iter'+str(i)+'.out',newarray,fmt='%.4e')
# Out:
# 0.793617829828
# 0.492379780115
# 0.421213432122
# 0.307119024857
# 0.249535133843
# 0.194533699809

# %%
np.savetxt?

# %%
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)
fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)
xx = np.linspace(-np.pi, np.pi, 26)
for i in [1,3,5,7]:
    data=np.loadtxt('fes1d2_iter%d.out' %i)
    plt.plot(data[:,0],-data[:,1]/4.184,lw=2.2,label='iter%d0' %i)
    
for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
leg=plt.legend(loc=0, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1)
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
plt.ylabel(r'free energy (kcal/mol)',fontproperties=font_prop)
plt.xlabel(r'angle (rad)',fontproperties=font_prop)
#plt.ylim(1,10000)
plt.savefig('Energy_CV1.png',dpi=600,bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-1f2dc996d01a> in <module>
#      12 xx = np.linspace(-np.pi, np.pi, 26)
#      13 for i in [1,3,5,7]:
# ---> 14     data=np.loadtxt('fes1d2_iter%d.out' %i)
#      15     plt.plot(data[:,0],-data[:,1]/4.184,lw=2.2,label='iter%d0' %i)
#      16
#
# ~/software/anaconda3/envs/py3.6/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     803                 fh = iter(open(fname, 'U'))
#     804             else:
# --> 805                 fh = iter(open(fname))
#     806         else:
#     807             fh = iter(fname)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fes1d2_iter1.out'

# %%
import numpy as np
a=np.array([1,2,3,4])
temp=[]
temp.append(a)
temp.append(a)

# %%
np.mean(temp,axis=0)
# Out:
# array([ 1.,  2.,  3.,  4.])

# %%
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)
fig = plt.figure(figsize=(4.8,4))
sub = fig.add_subplot(1,1,1)
cv=3
for i in [1,2,3,4,5]:
    data=np.loadtxt('fes1d2_iter%d.out' %i)
    plt.plot(data[:,0],-data[:,cv]/4.184,lw=2.2,label='iter%d0' %i)
    plt.fill_between(data[:,0], -data[:,cv]/4.184 - data[:,cv+3]/4.184,-data[:,cv]/4.184 + data[:,cv+3]/4.184, alpha=0.4 )
for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(22)
plt.ylim(-0.5,9)
leg=plt.legend(loc=2, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1,bbox_to_anchor=(1.01,1.0))
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
plt.ylabel(r'free energy (kcal/mol)',fontproperties=font_prop)
plt.xlabel(r'angle (rad)',fontproperties=font_prop)
#plt.ylim(1,10000)
plt.savefig('Energy2_CV%d.png' %cv,dpi=600,bbox_inches='tight')
plt.show()

# %%
pwd
# Out:
# '/scratch/gpfs/dongdong/chi1.run02/data'

# %%
for i in range(4,5):
    dirname='iter%d0' %i
    data=np.loadtxt(dirname+'/fe.out')
    newarray=[]
    for aa in data:
        if aa[0]<0:
            bb=aa[0]+2*np.pi
        else:
            bb=aa[0]
        if aa[1]<0:
            cc=aa[1]+2*np.pi
        else:
            cc=aa[1]
        temp=[]
        temp.append(bb)
        temp.append(cc)
        temp.append(aa[2])
        temp.append(aa[3])
        temp.append(aa[4])
        temp=np.array(temp)
        newarray.append(temp)
    newarray=np.array(newarray)
    idex=np.lexsort([newarray[:,1], newarray[:,0]])
    sorted_data = newarray[idex,:]
    np.savetxt('fes2d_iter'+str(i)+'.out',sorted_data,fmt='%.4e')

# %%
data=np.loadtxt('fes2d_iter5.out')
fig = plt.figure(figsize=(5.1, 4))
ax = fig.add_subplot(111)
cmap = plt.cm.get_cmap("jet_r")
#CS = plt.contourf(xedges[1:],yedges[1:],H,levels = np.linspace(0,1000000,11),cmap=cmap,extend="max")
#lvls = np.logspace(0,3,15)
cmap.set_over("white")
xi = np.linspace(0, 2*np.pi, 25)
CS = plt.contourf(xi,xi,np.reshape(-data[:,2]/4.184,(-1,25)).T,levels = np.linspace(0,14,15),cmap=cmap,extend="max")
#CS = plt.contourf(xi,xi,np.reshape(data[:,2]/4.18,(-1,61)),cmap=cmap,extend="max")
cbar = plt.colorbar(CS)
#plt.scatter(data_ave[:,0],data_ave[:,1],s=18)
#plt.scatter(data_ave[:,0],data_ave[:,1],c=pcca,cmap='tab20c',s=14)
#plt.errorbar(data_ave[:,2],data_ave[:,0],xerr=data_ave[:,3],yerr=data_ave[:,1],fmt=None)
plt.xlabel(r'$\mathregular{\phi}$ (rad)',fontproperties=font_prop)
plt.ylabel(r'$\psi$ (rad)',fontproperties=font_prop)
#plt.xlabel(r'$\phi$ (rad)')
#plt.xlim(0,0.45)
#plt.ylim(0,1)
#leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
#leg.get_frame().set_linewidth(0.0)
#leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()+cbar.ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
for label in cbar.ax.get_yticklabels():
    label.set_fontproperties(leg_prop)
plt.savefig('free_energy2d_iter50.png',dpi=600,bbox_inches='tight')
    #label.set_fontsize(16)
#plt.imshow(HH, interpolation='nearest', origin='low',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],levels = np.linspace(1,6,20))
plt.show()

# %%
data=np.loadtxt('fes2d_iter4.out')
fig = plt.figure(figsize=(5.1, 4))
ax = fig.add_subplot(111)
cmap = plt.cm.get_cmap("jet_r")
#CS = plt.contourf(xedges[1:],yedges[1:],H,levels = np.linspace(0,1000000,11),cmap=cmap,extend="max")
#lvls = np.logspace(0,3,15)
cmap.set_over("white")
xi = np.linspace(0, 2*np.pi, 25)
CS = plt.contourf(xi,xi,np.reshape(-data[:,2]/4.184,(-1,25)).T,levels = np.linspace(0,14,15),cmap=cmap,extend="max")
#CS = plt.contourf(xi,xi,np.reshape(data[:,2]/4.18,(-1,61)),cmap=cmap,extend="max")
cbar = plt.colorbar(CS)
#plt.scatter(data_ave[:,0],data_ave[:,1],s=18)
#plt.scatter(data_ave[:,0],data_ave[:,1],c=pcca,cmap='tab20c',s=14)
#plt.errorbar(data_ave[:,2],data_ave[:,0],xerr=data_ave[:,3],yerr=data_ave[:,1],fmt=None)
plt.xlabel(r'$\mathregular{\phi}$ (rad)',fontproperties=font_prop)
plt.ylabel(r'$\psi$ (rad)',fontproperties=font_prop)
#plt.xlabel(r'$\phi$ (rad)')
#plt.xlim(0,0.45)
#plt.ylim(0,1)
#leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
#leg.get_frame().set_linewidth(0.0)
#leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()+cbar.ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
for label in cbar.ax.get_yticklabels():
    label.set_fontproperties(leg_prop)
plt.savefig('free_energy2d_iter40.png',dpi=600,bbox_inches='tight')
    #label.set_fontsize(16)
#plt.imshow(HH, interpolation='nearest', origin='low',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],levels = np.linspace(1,6,20))
plt.show()

# %%
zero_grid  = np.zeros((ngrid,1))

# %%
len(zero_grid)
# Out:
# 24

# %%
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)

# %%
cd /home/dongdong/SCR/chi1.run02/iter50/test2
# Out:
# /scratch/gpfs/dongdong/chi1.run02/iter50/test2

# %%
xi = np.linspace(0, 2*np.pi, 25)

# %%
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)
data=np.loadtxt('/home/dongdong/SCR/chi1.run02/iter50/test2/2CV_step900000.dat')
fig = plt.figure(figsize=(5.1, 4))
ax = fig.add_subplot(111)
cmap = plt.cm.get_cmap("jet_r")
#CS = plt.contourf(xedges[1:],yedges[1:],H,levels = np.linspace(0,1000000,11),cmap=cmap,extend="max")
#lvls = np.logspace(0,3,15)
cmap.set_over("white")
xi = np.linspace(0, 2*np.pi, 25)
CS = plt.contourf(xi,xi,data,levels = np.linspace(0,14,15),cmap=cmap,extend="max")
#CS = plt.contourf(xi,xi,np.reshape(data[:,2]/4.18,(-1,61)),cmap=cmap,extend="max")
cbar = plt.colorbar(CS)
#plt.scatter(data_ave[:,0],data_ave[:,1],s=18)
#plt.scatter(data_ave[:,0],data_ave[:,1],c=pcca,cmap='tab20c',s=14)
#plt.errorbar(data_ave[:,2],data_ave[:,0],xerr=data_ave[:,3],yerr=data_ave[:,1],fmt=None)
plt.xlabel(r'$\mathregular{\phi}$ (rad)',fontproperties=font_prop)
plt.ylabel(r'$\psi$ (rad)',fontproperties=font_prop)
#plt.xlabel(r'$\phi$ (rad)')
#plt.xlim(0,0.45)
#plt.ylim(0,1)
#leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
#leg.get_frame().set_linewidth(0.0)
#leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()+cbar.ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
for label in cbar.ax.get_yticklabels():
    label.set_fontproperties(leg_prop)
#plt.savefig('2CV_step900000.png',dpi=600,bbox_inches='tight')
    #label.set_fontsize(16)
#plt.imshow(HH, interpolation='nearest', origin='low',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],levels = np.linspace(1,6,20))
plt.show()

# %%
fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)
xx = np.linspace(-np.pi, np.pi, 25)
data=np.loadtxt('1CV_index0.dat')
i=1
for i in [6,12,18]:
    lab=i*5/10
    plt.plot(xx,data[i],lw=2.2,label=r'step %d $\mathregular{\times 10^5}$' %lab)

    
for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
leg=plt.legend(loc=2, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1,bbox_to_anchor=(1.01,1.0))
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
plt.ylabel(r'free energy (kcal/mol)',fontproperties=font_prop)
plt.xlabel(r'angle (rad)',fontproperties=font_prop)
#plt.ylim(1,10000)
plt.savefig('Energy_CV1.png',dpi=600,bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)
xx = np.linspace(-np.pi, np.pi, 25)
data=np.loadtxt('1CV_index1.dat')
i=1
for i in [6,12,18]:
    lab=i*5/10
    plt.plot(xx,data[i],lw=2.2,label=r'step %d $\mathregular{\times 10^5}$' %lab)

    
for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
leg=plt.legend(loc=2, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1,bbox_to_anchor=(1.01,1.0))
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
plt.ylabel(r'free energy (kcal/mol)',fontproperties=font_prop)
plt.xlabel(r'angle (rad)',fontproperties=font_prop)
#plt.ylim(1,10000)
plt.savefig('Energy_CV2.png',dpi=600,bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)
xx = np.linspace(-np.pi, np.pi, 25)
data=np.loadtxt('1CV_index2.dat')
i=1
for i in [6,12,18]:
    lab=i*5/10
    plt.plot(xx,data[i],lw=2.2,label=r'step %d $\mathregular{\times 10^5}$' %lab)

    
for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
leg=plt.legend(loc=2, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1,bbox_to_anchor=(1.01,1.0))
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
plt.ylabel(r'free energy (kcal/mol)',fontproperties=font_prop)
plt.xlabel(r'angle (rad)',fontproperties=font_prop)
#plt.ylim(1,10000)
plt.savefig('Energy_CV3.png',dpi=600,bbox_inches='tight')
plt.show()

# %%
xx = np.linspace(0, 2*np.pi, 25)
for iii in range(9):
    fig = plt.figure(figsize=(5,4))
    sub = fig.add_subplot(1,1,1)
    data=np.loadtxt('/home/dongdong/SCR/chi3.run01/mc/iter140_0/1CV_index%d.dat' %iii)
    i=1
    for i in [12,16,20]:
        lab=i*5/10
        plt.plot(xx,data[i],lw=2.2,label=r'step %d $\mathregular{\times 10^5}$' %lab)
    
        
    for label in (sub.get_xticklabels() + sub.get_yticklabels()):
        label.set_fontproperties(font_prop)
        label.set_fontsize(16)
    leg=plt.legend(loc=2, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1,bbox_to_anchor=(1.01,1.0))
    leg.get_frame().set_linewidth(0.0)
    leg.get_frame().set_alpha(0.1)
    plt.ylabel(r'free energy (kcal/mol)',fontproperties=font_prop)
    plt.xlabel(r'angle (rad)',fontproperties=font_prop)
    #plt.ylim(1,10000)
    plt.savefig('/home/dongdong/SCR/chi3.run01/mc/iter140_0/Energy_CV%d.png' %iii,dpi=600,bbox_inches='tight')
    plt.show()

# %%
fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)
xx = np.linspace(-np.pi, np.pi, 25)
data=np.loadtxt('/home/dongdong/SCR/chi3.run01/mc/iter120/1CV_index0.dat')
i=1
for i in range(len(data)):
    lab=i*5/10
    plt.plot(xx,data[i]-np.min(data[i]),lw=2.2,label=r'step %d $\mathregular{\times 10^5}$' %lab)

    
for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
leg=plt.legend(loc=2, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1,bbox_to_anchor=(1.01,1.0))
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
plt.ylabel(r'free energy (kcal/mol)',fontproperties=font_prop)
plt.xlabel(r'angle (rad)',fontproperties=font_prop)
#plt.ylim(1,10000)
plt.savefig('/home/dongdong/SCR/chi3.run01/mc/iter120/Energy_CV0.png',dpi=600,bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)
xx = np.linspace(-np.pi, np.pi, 25)
data=np.loadtxt('/home/dongdong/SCR/chi3.run01/mc/iter100/1CV_index0.dat')
i=1
for i in range(len(data)):
    lab=i*5/10
    plt.plot(xx,data[i]-np.min(data[i]),lw=2.2,label=r'step %d $\mathregular{\times 10^5}$' %lab)

    
for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
leg=plt.legend(loc=2, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1,bbox_to_anchor=(1.01,1.0))
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
plt.ylabel(r'free energy (kcal/mol)',fontproperties=font_prop)
plt.xlabel(r'angle (rad)',fontproperties=font_prop)
#plt.ylim(1,10000)
plt.savefig('/home/dongdong/SCR/chi3.run01/mc/iter100/Energy_CV0.png',dpi=600,bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)
xx = np.linspace(-np.pi, np.pi, 25)
data=np.loadtxt('/home/dongdong/SCR/chi3.run01/mc/iter140/1CV_index0.dat')
i=1
for i in range(len(data)):
    lab=i*5/10
    plt.plot(xx,data[i]-np.min(data[i]),lw=2.2,label=r'step %d $\mathregular{\times 10^5}$' %lab)

    
for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
leg=plt.legend(loc=2, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1,bbox_to_anchor=(1.01,1.0))
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
plt.ylabel(r'free energy (kcal/mol)',fontproperties=font_prop)
plt.xlabel(r'angle (rad)',fontproperties=font_prop)
#plt.ylim(1,10000)
plt.savefig('/home/dongdong/SCR/chi3.run01/mc/iter140/Energy_CV0.png',dpi=600,bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)
xx = np.linspace(-np.pi, np.pi, 25)
data=np.loadtxt('/home/dongdong/SCR/chi3.run01/mc/iter80/1CV_index0.dat')
i=1
for i in range(len(data)):
    lab=i*5/10
    plt.plot(xx,data[i]-np.min(data[i]),lw=2.2,label=r'step %d $\mathregular{\times 10^5}$' %lab)

    
for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
leg=plt.legend(loc=2, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1,bbox_to_anchor=(1.01,1.0))
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
plt.ylabel(r'free energy (kcal/mol)',fontproperties=font_prop)
plt.xlabel(r'angle (rad)',fontproperties=font_prop)
#plt.ylim(1,10000)
plt.savefig('/home/dongdong/SCR/chi3.run01/mc/iter80/Energy_CV0.png',dpi=600,bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(5,4))
sub = fig.add_subplot(1,1,1)
xx = np.linspace(-np.pi, np.pi, 25)
for jj in [2,6,8,10]:
    data=np.loadtxt('/home/dongdong/SCR/chi3.run01/mc/iter%d0/1CV_index0.dat' %jj)
    plt.plot(xx,data[-1]-np.min(data[-1]),lw=2.2,label=r'iter%d0' %jj)

    
for label in (sub.get_xticklabels() + sub.get_yticklabels()):
    label.set_fontproperties(font_prop)
    label.set_fontsize(16)
leg=plt.legend(loc=2, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1,bbox_to_anchor=(1.01,1.0))
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.1)
plt.ylabel(r'free energy (kcal/mol)',fontproperties=font_prop)
plt.xlabel(r'angle (rad)',fontproperties=font_prop)
#plt.ylim(1,10000)
#plt.savefig('/home/dongdong/SCR/chi3.run01/mc/Energy_CV0_all.png',dpi=600,bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-32cc27e01f69> in <module>
#       3 xx = np.linspace(-np.pi, np.pi, 25)
#       4 for jj in [2,6,8,10]:
# ----> 5     data=np.loadtxt('/home/dongdong/SCR/chi3.run01/mc/iter%d0/1CV_index0.dat' %jj)
#       6     plt.plot(xx,data[-1]-np.min(data[-1]),lw=2.2,label=r'iter%d0' %jj)
#       7
#
# ~/software/anaconda3/envs/py3.6/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     803                 fh = iter(open(fname, 'U'))
#     804             else:
# --> 805                 fh = iter(open(fname))
#     806         else:
#     807             fh = iter(fname)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/dongdong/SCR/chi3.run01/mc/iter60/1CV_index0.dat'

# %%
xx = np.linspace(0, 2*np.pi, 25)
for cv in range(9):
    
    fig = plt.figure(figsize=(4.8,4))
    sub = fig.add_subplot(1,1,1)
    for jj in [2,6,10,14]:
        alldata=[]
        for kk in range(4):
            data=np.loadtxt('/home/dongdong/SCR/chi3.run01/mc/iter%d0_%d/1CV_index%d.dat' %(jj,kk,cv))
            alldata.append(data[-1]-np.min(data[-1]))
        ave=np.mean(alldata,axis=0)
        sd=np.std(alldata,axis=0)
        plt.plot(xx,ave,lw=2.2,label=r'iter%d0' %jj)
        plt.fill_between(xx, ave - sd,ave + sd, alpha=0.4 )
        plt.ylim(-0.4,9)
    for label in (sub.get_xticklabels() + sub.get_yticklabels()):
        label.set_fontproperties(font_prop)
        label.set_fontsize(22)
    leg=plt.legend(loc=2, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1,bbox_to_anchor=(1.01,1.0))
    leg.get_frame().set_linewidth(0.0)
    leg.get_frame().set_alpha(0.1)
    plt.ylabel(r'free energy (kcal/mol)',fontproperties=font_prop)
    plt.xlabel(r'angle (rad)',fontproperties=font_prop)
    #plt.ylim(1,10000)
    plt.savefig('/home/dongdong/SCR/chi3.run01/mc/Energy_CV%d_all.png' %cv,dpi=600,bbox_inches='tight')
    plt.show()

# %%
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)
alldata=np.zeros((25,25))
for i in range(4):
    data=np.loadtxt('/home/dongdong/SCR/chi3.run01/mc/iter140_%d/2CV12_step1000000.dat' %i)
    alldata+=data
fig = plt.figure(figsize=(5.1, 4))
ax = fig.add_subplot(111)
cmap = plt.cm.get_cmap("jet_r")
#CS = plt.contourf(xedges[1:],yedges[1:],H,levels = np.linspace(0,1000000,11),cmap=cmap,extend="max")
#lvls = np.logspace(0,3,15)
cmap.set_over("white")
xi = np.linspace(0, 2*np.pi, 25)
CS = plt.contourf(xi,xi,alldata/4.0-np.min(alldata/4.0),levels = np.linspace(0,14,15),cmap=cmap,extend="max")
#CS = plt.contourf(xi,xi,np.reshape(data[:,2]/4.18,(-1,61)),cmap=cmap,extend="max")
cbar = plt.colorbar(CS)
#plt.scatter(data_ave[:,0],data_ave[:,1],s=18)
#plt.scatter(data_ave[:,0],data_ave[:,1],c=pcca,cmap='tab20c',s=14)
#plt.errorbar(data_ave[:,2],data_ave[:,0],xerr=data_ave[:,3],yerr=data_ave[:,1],fmt=None)
plt.xlabel(r'$\mathregular{\phi_1}$ (rad)',fontproperties=font_prop)
plt.ylabel(r'$\psi\mathregular{_1}$ (rad)',fontproperties=font_prop)
#plt.xlabel(r'$\phi$ (rad)')
#plt.xlim(0,0.45)
#plt.ylim(0,1)
#leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
#leg.get_frame().set_linewidth(0.0)
#leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()+cbar.ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
for label in cbar.ax.get_yticklabels():
    label.set_fontproperties(leg_prop)
plt.savefig('/home/dongdong/SCR/chi3.run01/mc/2CV12_iter140.png',dpi=600,bbox_inches='tight')
    #label.set_fontsize(16)
#plt.imshow(HH, interpolation='nearest', origin='low',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],levels = np.linspace(1,6,20))
plt.show()

# %%
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)
alldata=np.zeros((25,25))
for i in range(4):
    data=np.loadtxt('/home/dongdong/SCR/chi3.run01/mc/iter140_%d/2CV45_step1000000.dat' %i)
    alldata+=data
fig = plt.figure(figsize=(5.1, 4))
ax = fig.add_subplot(111)
cmap = plt.cm.get_cmap("jet_r")
#CS = plt.contourf(xedges[1:],yedges[1:],H,levels = np.linspace(0,1000000,11),cmap=cmap,extend="max")
#lvls = np.logspace(0,3,15)
cmap.set_over("white")
xi = np.linspace(0, 2*np.pi, 25)
CS = plt.contourf(xi,xi,alldata/4.0-np.min(alldata/4.0),levels = np.linspace(0,14,15),cmap=cmap,extend="max")
#CS = plt.contourf(xi,xi,np.reshape(data[:,2]/4.18,(-1,61)),cmap=cmap,extend="max")
cbar = plt.colorbar(CS)
#plt.scatter(data_ave[:,0],data_ave[:,1],s=18)
#plt.scatter(data_ave[:,0],data_ave[:,1],c=pcca,cmap='tab20c',s=14)
#plt.errorbar(data_ave[:,2],data_ave[:,0],xerr=data_ave[:,3],yerr=data_ave[:,1],fmt=None)
plt.xlabel(r'$\mathregular{\phi_2}$ (rad)',fontproperties=font_prop)
plt.ylabel(r'$\psi\mathregular{_2}$ (rad)',fontproperties=font_prop)
#plt.xlabel(r'$\phi$ (rad)')
#plt.xlim(0,0.45)
#plt.ylim(0,1)
#leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
#leg.get_frame().set_linewidth(0.0)
#leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()+cbar.ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
for label in cbar.ax.get_yticklabels():
    label.set_fontproperties(leg_prop)
plt.savefig('/home/dongdong/SCR/chi3.run01/mc/2CV45_iter140.png',dpi=600,bbox_inches='tight')
    #label.set_fontsize(16)
#plt.imshow(HH, interpolation='nearest', origin='low',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],levels = np.linspace(1,6,20))
plt.show()

# %%
import numpy as np
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_path = '/home/dongdong/tigress/calibribold.ttf'
font_prop = font_manager.FontProperties(fname=font_path, size=24)
leg_prop = font_manager.FontProperties(fname=font_path, size=18)
alldata=np.zeros((25,25))
for i in range(4):
    data=np.loadtxt('/home/dongdong/SCR/chi3.run01/mc/iter140_%d/2CV78_step1000000.dat' %i)
    alldata+=data
fig = plt.figure(figsize=(5.1, 4))
ax = fig.add_subplot(111)
cmap = plt.cm.get_cmap("jet_r")
#CS = plt.contourf(xedges[1:],yedges[1:],H,levels = np.linspace(0,1000000,11),cmap=cmap,extend="max")
#lvls = np.logspace(0,3,15)
cmap.set_over("white")
xi = np.linspace(0, 2*np.pi, 25)
CS = plt.contourf(xi,xi,alldata/4.0-np.min(alldata/4.0),levels = np.linspace(0,14,15),cmap=cmap,extend="max")
#CS = plt.contourf(xi,xi,np.reshape(data[:,2]/4.18,(-1,61)),cmap=cmap,extend="max")
cbar = plt.colorbar(CS)
#plt.scatter(data_ave[:,0],data_ave[:,1],s=18)
#plt.scatter(data_ave[:,0],data_ave[:,1],c=pcca,cmap='tab20c',s=14)
#plt.errorbar(data_ave[:,2],data_ave[:,0],xerr=data_ave[:,3],yerr=data_ave[:,1],fmt=None)
plt.xlabel(r'$\mathregular{\phi_3}$ (rad)',fontproperties=font_prop)
plt.ylabel(r'$\psi\mathregular{_3}$ (rad)',fontproperties=font_prop)

#plt.xlabel(r'$\phi$ (rad)')
#plt.xlim(0,0.45)
#plt.ylim(0,1)
#leg=plt.legend(loc=1, labelspacing=0.1, prop=leg_prop, scatterpoints=1, markerscale=1, numpoints=1,handlelength=1.5)
#leg.get_frame().set_linewidth(0.0)
#leg.get_frame().set_alpha(0.1)
for label in (ax.get_xticklabels() + ax.get_yticklabels()+cbar.ax.get_yticklabels()):
    label.set_fontproperties(font_prop)
for label in cbar.ax.get_yticklabels():
    label.set_fontproperties(leg_prop)
plt.savefig('/home/dongdong/SCR/chi3.run01/mc/2CV78_iter140.png',dpi=600,bbox_inches='tight')
    #label.set_fontsize(16)
#plt.imshow(HH, interpolation='nearest', origin='low',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],levels = np.linspace(1,6,20))
plt.show()

# %%
it=0
en=0
trjdir='/home/dongdong/SCR/chi3.run01/iter.%06d/00.enhcMD/%03d/' %(it,en)

# %%
import numpy as np
plmf=trjdir+'plm.out'
data=np.loadtxt(plmf)[:,1:]

# %%
data
# Out:
# array([[-3.087558, -1.483479, -2.572648, ...,  0.054465,  1.594765,
#          3.122281],
#        [ 2.722923, -1.535967, -2.578583, ..., -0.076492,  1.500929,
#          3.098319],
#        [-3.088047, -1.492751, -2.510439, ..., -0.439729,  1.715593,
#          2.800628],
#        ...,
#        [-2.970236, -1.650664, -2.761842, ..., -0.22341 ,  1.35049 ,
#          3.055303],
#        [-3.049289, -1.546225, -2.805193, ..., -0.251474,  1.319272, -3.0845  ],
#        [ 3.00439 , -1.367197, -2.939572, ..., -0.194623,  1.523895,
#          2.822902]])
